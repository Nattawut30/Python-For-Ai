# %%
# SPLITTING DATA 0

# ML = we train the model and we evaluate the model on different data!
# What does a cat looks like? what does a dog looks like? if you never seen them ever...
# So i show you pictures of cats and dogs and you train to recognize cats and dogs based on the pictures
# BTW, you performing well on these pictues doesn't mean you understood what cats and dogs are ...
# Maybe you just memorized these pictures and you understood, this one is a cat, this one is a dog

# You don't generalize. You don't understand the feature of a cat and a dog
# You just recognize the feature the pictures that you already saw
# Basically, you memorize it well.

# Train 1 portions of the data -> Evaluate on an unseen portion of the data 

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

X, y = load_iris(return_X_y=True)

train_test_split(X, y, test_size=0.2) # 20% testing, 80% trainning
# Out:
# [array([[6.3, 3.3, 6. , 2.5],
#         [5.8, 2.6, 4. , 1.2],
#         [4.9, 3. , 1.4, 0.2],
#         [5.1, 2.5, 3. , 1.1],
#         [5.6, 2.5, 3.9, 1.1],
#         [6.7, 2.5, 5.8, 1.8],
#         [6.8, 2.8, 4.8, 1.4],
#         [5.7, 2.8, 4.1, 1.3],
#         [5. , 3.4, 1.5, 0.2],
#         [6.7, 3.3, 5.7, 2.5],
#         [4.9, 2.4, 3.3, 1. ],
#         [5.7, 2.5, 5. , 2. ],
#         [5. , 3.2, 1.2, 0.2],
#         [5.1, 3.5, 1.4, 0.2],
#         [5. , 3.5, 1.6, 0.6],
#         [6.8, 3. , 5.5, 2.1],
#         [5. , 3.6, 1.4, 0.2],
#         [5.1, 3.3, 1.7, 0.5],
#         [4.8, 3. , 1.4, 0.1],
#         [6. , 2.2, 4. , 1. ],
#         [5.6, 2.8, 4.9, 2. ],
#         [5.8, 2.7, 4.1, 1. ],
#         [5.2, 3.4, 1.4, 0.2],
#         [7. , 3.2, 4.7, 1.4],
#         [4.9, 3.1, 1.5, 0.1],
#         [6.7, 3. , 5.2, 2.3],
#         [6. , 2.2, 5. , 1.5],
#         [5.6, 2.9, 3.6, 1.3],
#         [5.5, 2.4, 3.7, 1. ],
#         [6.4, 2.7, 5.3, 1.9],
#         [5.7, 3.8, 1.7, 0.3],
# ...

# %%
len(X) 

# 150 instances
# Out:
# 150

# %%
print(0.2*150) 

# not train on this 30 instanes, only train 120 instances and then evaluate how well the model performs on the remaining 20%
# Out:
# 30.0

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

data = load_iris()

X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(X_train)
# Out:
# 120

# %%
len(X_test)
# Out:
# 30

# %%
import numpy as np
import matplotlib.pyplot as plt

# I can do a visualization. I can see what is the distribution of the classifications of the labels
# If i have a training set where let's say one or two classses are disproportionately present whereas one of the classes is not present at all
# or only a few in the training data set. completely flipped = completely opposite
# then my evaluation is very meaningful because I'm working with different datasets!

counts = np.bincount(y_train)
positions = np.arange(3)

plt.bar(positions, counts)
plt.xticks(positions, data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x115d69550>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
# We now train but let's do some test: y_test

import numpy as np
import matplotlib.pyplot as plt

counts = np.bincount(y_test)
positions = np.arange(3)

plt.bar(positions, counts)
plt.xticks(positions, data.target_names)

# As you can see it's exactly the opposite...
# If I evaluate on this, it might lead to problem and maybe my evaluations is not really perfect in this case
# Out:
# ([<matplotlib.axis.XTick at 0x115eb0cd0>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
from sklearn.model_selection import StratifiedShuffleSplit
# It's guarantees or it pays attention to having a similar distributions.
# To having the same ratio of the different classes in the training and the testing datasets

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)

for train_index, test_index in split.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
